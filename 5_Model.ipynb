# %%
import os
import datetime
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import Tracab as tracab
import Tracking_Visuals as vis
import Tracking_Velocities as vel
import Tracking_Fatigue as fatigue
import helpers
import importlib
# importlib.reload(tracab)
# importlib.reload(helpers)
# importlib.reload(vis)

# %% [markdown]
# # Read player and energy expenditure data

# %%
# EX data
with open(os.path.join('./saved', 'all_time_series.pkl'), 'rb') as infile:
    data_dict = pickle.load(infile)

# %%
# players data
players_df = pd.read_csv('../playerid_jerseynum_map.csv')

# %%
players_df
# Out:
#       Match ID  Team  Playerid           Player name  Jersey Num  \
# 0       984455  Home     50310     Sebastian Mielitz          28
# 1       984455  Home    247047      Nicholas Marfelt          18
# 2       984455  Home    207273     Stefan Gartenmann           2
# 3       984455  Home     56317          Kees Luijckx           5
# 4       984455  Home     52560         Marc Pedersen           3
# ...        ...   ...       ...                   ...         ...
# 6251    984634  Away     90125       Jacob Tjrnelund           4
# 6252    984634  Away    225006  Julian Kristoffersen          19
# 6253    984634  Away    429775   Adrian Kappenberger          31
# 6254    984634  Away    425086      Christian Cappis          18
# 6255    984634  Away    460836    Mathies Skjellerup          28
#
#      Starting Position Starts Match start_pos_super first_name      last_name
# 0                   GK        Start              GK  Sebastian        Mielitz
# 1                  LFB        Start               D   Nicholas        Marfelt
# 2                  RFB        Start               D     Stefan     Gartenmann
# 3                   CD        Start               D       Kees        Luijckx
# 4                   CD        Start               D       Marc       Pedersen
# ...                ...          ...             ...        ...            ...
# 6251               Sub          Sub             Sub      Jacob      Tjrnelund
# 6252               Sub          Sub             Sub     Julian  Kristoffersen
# 6253               Sub          Sub             Sub     Adrian   Kappenberger
# 6254               Sub          Sub             Sub  Christian         Cappis
# 6255               Sub          Sub             Sub    Mathies     Skjellerup
#
# [6256 rows x 10 columns]

# %%
for player, positions in players_df[['Playerid', 'start_pos_super']]\
        .groupby('Playerid')['start_pos_super'].apply(list).iteritems():
    print(player, np.unique(positions))
# Out:
# 3489 ['F' 'Sub']
# 4611 ['Sub']
# 13737 ['M' 'Sub']
# 13994 ['M' 'Sub']
# 14190 ['GK' 'Sub']
# 14353 ['F' 'M' 'Sub']
# 14815 ['Sub']
# 18150 ['M' 'Sub']
# 19685 ['F' 'Sub']
# 20086 ['D' 'Sub']
# 21103 ['D']
# 27261 ['M' 'Sub']
# 28673 ['Sub']
# 39643 ['GK' 'Sub']
# 39664 ['M' 'Sub']
# 39737 ['D' 'F' 'M' 'Sub']
# 39738 ['F' 'M' 'Sub']
# 40231 ['M' 'Sub']
# 40690 ['Sub']
# 41086 ['M']
# 41097 ['F' 'Sub']
# 41343 ['D' 'Sub']
# 45097 ['D' 'F' 'M' 'Sub']
# 48337 ['F']
# 48469 ['D' 'Sub']
# 48597 ['M' 'Sub']
# 48601 ['D' 'M' 'Sub']
# 48715 ['D' 'Sub']
# 48723 ['M' 'Sub']
# 48733 ['D' 'Sub']
# 49829 ['D']
# 50310 ['GK']
# 50647 ['D' 'Sub']
# 51585 ['D' 'M' 'Sub']
# 51653 ['Sub']
# 51656 ['D' 'M' 'Sub']
# 51658 ['GK']
# 51664 ['M' 'Sub']
# 51668 ['D' 'Sub']
# 51705 ['GK']
# 51988 ['D' 'Sub']
# 51998 ['M' 'Sub']
# 52005 ['D' 'M' 'Sub']
# 52057 ['D' 'M' 'Sub']
# 52560 ['D']
# 52622 ['D']
# 52644 ['M' 'Sub']
# 55690 ['D' 'Sub']
# 55903 ['M' 'Sub']
# 56317 ['D']
# 56625 ['D' 'Sub']
# 57059 ['D' 'Sub']
# 57076 ['D' 'Sub']
# 58863 ['F' 'Sub']
# 60638 ['F' 'M' 'Sub']
# 60724 ['D']
# 61527 ['D']
# 61778 ['F' 'M' 'Sub']
# 62016 ['GK']
# 62811 ['M']
# 62825 ['D' 'Sub']
# 66912 ['M' 'Sub']
# 68250 ['GK']
# 68761 ['M']
# 70017 ['M' 'Sub']
# 70988 ['D' 'Sub']
# 71407 ['F' 'Sub']
# 75966 ['D']
# 76001 ['M']
# 76008 ['D' 'Sub']
# 76230 ['F' 'M' 'Sub']
# 76507 ['M' 'Sub']
# 77384 ['D' 'Sub']
# 77443 ['D' 'Sub']
# 79462 ['D' 'M' 'Sub']
# 79921 ['D' 'Sub']
# 80398 ['D' 'Sub']
# 80502 ['D']
# 80841 ['F' 'Sub']
# 81185 ['M' 'Sub']
# 82062 ['F' 'Sub']
# 82070 ['Sub']
# 82294 ['F' 'Sub']
# 82830 ['D']
# 82834 ['Sub']
# 83572 ['F' 'Sub']
# 84359 ['M']
# 84490 ['GK']
# 84500 ['F' 'M' 'Sub']
# 84533 ['D']
# 84870 ['Sub']
# 85007 ['D' 'Sub']
# 85028 ['F' 'Sub']
# 85050 ['F']
# 85200 ['Sub']
# 85310 ['F' 'Sub']
# 85661 ['Sub']
# 85686 ['Sub']
# 86361 ['F' 'Sub']
# 86362 ['D' 'Sub']
# 88022 ['F' 'Sub']
# 88208 ['D' 'M' 'Sub']
# 88217 ['M' 'Sub']
# 88567 ['F' 'M' 'Sub']
# 89226 ['F' 'M' 'Sub']
# 89408 ['Sub']
# 89443 ['M' 'Sub']
# 90125 ['D' 'Sub']
# 90142 ['F' 'M' 'Sub']
# 90883 ['M' 'Sub']
# 92795 ['D' 'M' 'Sub']
# 93777 ['M']
# 94694 ['GK' 'Sub']
# 95169 ['M' 'Sub']
# 95194 ['F' 'Sub']
# 95417 ['F' 'Sub']
# 95544 ['F' 'M' 'Sub']
# 95668 ['Sub']
# 96133 ['D' 'M' 'Sub']
# 96565 ['D' 'Sub']
# 96765 ['F' 'Sub']
# 97672 ['Sub']
# 98650 ['D' 'M' 'Sub']
# 98733 ['F' 'Sub']
# 100399 ['GK' 'Sub']
# 101298 ['M' 'Sub']
# 101999 ['F' 'M' 'Sub']
# 102005 ['D']
# 102010 ['D' 'Sub']
# 102020 ['Sub']
# 102912 ['M' 'Sub']
# 103742 ['Sub']
# 103916 ['Sub']
# 104173 ['Sub']
# 104291 ['D' 'Sub']
# 106325 ['D' 'Sub']
# 107961 ['M' 'Sub']
# 108024 ['D' 'Sub']
# 110927 ['D' 'Sub']
# 111282 ['F']
# 111319 ['GK' 'Sub']
# 112340 ['M' 'Sub']
# 113774 ['D' 'Sub']
# 113993 ['M' 'Sub']
# 114321 ['Sub']
# 114563 ['Sub']
# 114591 ['F' 'M']
# 114595 ['F' 'M' 'Sub']
# 115596 ['M']
# 115982 ['D' 'Sub']
# 116187 ['F' 'M' 'Sub']
# 116696 ['M']
# 116697 ['D' 'Sub']
# 116717 ['D' 'M' 'Sub']
# 118239 ['F' 'Sub']
# 119089 ['F' 'M' 'Sub']
# 119487 ['M' 'Sub']
# 120566 ['D' 'Sub']
# 121166 ['M' 'Sub']
# 123125 ['F' 'M' 'Sub']
# 123585 ['D' 'M' 'Sub']
# 124142 ['GK' 'Sub']
# 126317 ['M' 'Sub']
# 128295 ['M']
# 133894 ['M' 'Sub']
# 135354 ['D']
# 140246 ['D' 'Sub']
# 143288 ['Sub']
# 143744 ['D' 'Sub']
# 144045 ['GK']
# 144301 ['M']
# 147611 ['F' 'Sub']
# 150925 ['F' 'M' 'Sub']
# 152015 ['D' 'Sub']
# 153412 ['Sub']
# 153822 ['D' 'M' 'Sub']
# 155453 ['D' 'Sub']
# 155544 ['Sub']
# 155713 ['GK']
# 157312 ['Sub']
# 157665 ['M' 'Sub']
# 157670 ['Sub']
# 157685 ['F' 'Sub']
# 157704 ['F' 'Sub']
# 157815 ['D' 'Sub']
# 158554 ['D' 'M' 'Sub']
# 160212 ['M' 'Sub']
# 160844 ['D' 'M' 'Sub']
# 162037 ['M' 'Sub']
# 162038 ['M' 'Sub']
# 164266 ['D' 'Sub']
# 164545 ['F' 'M']
# 165112 ['M' 'Sub']
# 165718 ['Sub']
# 165824 ['D' 'Sub']
# 165858 ['D' 'Sub']
# 165923 ['D' 'Sub']
# 165925 ['D' 'F' 'M' 'Sub']
# 165927 ['GK' 'Sub']
# 166422 ['M' 'Sub']
# 166725 ['M' 'Sub']
# 167040 ['GK']
# 171158 ['F' 'M' 'Sub']
# 171580 ['GK' 'Sub']
# 171691 ['F' 'Sub']
# 172829 ['M' 'Sub']
# 175987 ['GK' 'Sub']
# 176432 ['D' 'Sub']
# 177888 ['Sub']
# 177899 ['M' 'Sub']
# 179251 ['Sub']
# 179437 ['Sub']
# 179459 ['F' 'Sub']
# 179464 ['F' 'Sub']
# 179468 ['F' 'Sub']
# 180169 ['D' 'F' 'M' 'Sub']
# 180662 ['D']
# 182413 ['GK']
# 183095 ['GK' 'Sub']
# 184269 ['F' 'M' 'Sub']
# 184691 ['M' 'Sub']
# 185061 ['M' 'Sub']
# 185121 ['D' 'Sub']
# 186663 ['F' 'Sub']
# 189664 ['F' 'Sub']
# 192100 ['D' 'M']
# 192158 ['F' 'M' 'Sub']
# 192161 ['D' 'M' 'Sub']
# 192205 ['Sub']
# 192647 ['M' 'Sub']
# 192779 ['D' 'M' 'Sub']
# 193046 ['F' 'Sub']
# 193200 ['Sub']
# 194625 ['F' 'Sub']
# 194808 ['D' 'M' 'Sub']
# 196239 ['F' 'M']
# 196705 ['Sub']
# 197804 ['F' 'Sub']
# 198920 ['F' 'Sub']
# 200069 ['F' 'M' 'Sub']
# 200880 ['M' 'Sub']
# 200933 ['F' 'M' 'Sub']
# 201068 ['F']
# 202259 ['Sub']
# 202456 ['D' 'Sub']
# 202918 ['F' 'M' 'Sub']
# 204164 ['M' 'Sub']
# 207273 ['D']
# 207276 ['D' 'Sub']
# 207280 ['D' 'M' 'Sub']
# 207326 ['F' 'Sub']
# 208695 ['D' 'M']
# 208904 ['D' 'Sub']
# 209721 ['D' 'Sub']
# 209987 ['F' 'M']
# 210069 ['D' 'M' 'Sub']
# 210339 ['F' 'Sub']
# 210956 ['D' 'Sub']
# 212394 ['F' 'M' 'Sub']
# 213155 ['M' 'Sub']
# 213294 ['F' 'Sub']
# 213296 ['F' 'M' 'Sub']
# 213398 ['D' 'Sub']
# 213602 ['M' 'Sub']
# 213786 ['D' 'M' 'Sub']
# 214642 ['D' 'F' 'M' 'Sub']
# 215101 ['D' 'Sub']
# 216228 ['D' 'M' 'Sub']
# 216557 ['Sub']
# 218300 ['F' 'Sub']
# 219009 ['M' 'Sub']
# 221234 ['D']
# 222353 ['D' 'F' 'M']
# 223842 ['D' 'Sub']
# 223843 ['Sub']
# 223851 ['Sub']
# 225006 ['F' 'Sub']
# 226885 ['M' 'Sub']
# 226956 ['D' 'Sub']
# 226967 ['F' 'M' 'Sub']
# 226969 ['M' 'Sub']
# 226970 ['Sub']
# 226972 ['M' 'Sub']
# 226973 ['F' 'Sub']
# 226975 ['F' 'Sub']
# 227062 ['F' 'M' 'Sub']
# 227118 ['Sub']
# 227386 ['M']
# 227701 ['D' 'M' 'Sub']
# 227937 ['F' 'M']
# 228043 ['D' 'Sub']
# 228058 ['F' 'M' 'Sub']
# 228951 ['Sub']
# 228952 ['Sub']
# 228955 ['D' 'Sub']
# 229217 ['M' 'Sub']
# 229218 ['M' 'Sub']
# 229219 ['F' 'M' 'Sub']
# 229221 ['Sub']
# 229223 ['D' 'Sub']
# 230198 ['F' 'Sub']
# 231223 ['Sub']
# 231698 ['F' 'M' 'Sub']
# 232016 ['D' 'Sub']
# 232018 ['D' 'M']
# 232904 ['GK']
# 233494 ['D' 'M' 'Sub']
# 235546 ['F' 'M']
# 235891 ['D' 'Sub']
# 241521 ['F' 'M' 'Sub']
# 242304 ['F' 'M' 'Sub']
# 243070 ['Sub']
# 243349 ['GK' 'Sub']
# 243724 ['M' 'Sub']
# 243784 ['Sub']
# 244164 ['Sub']
# 247047 ['D' 'M' 'Sub']
# 247384 ['Sub']
# 247431 ['D' 'F' 'M' 'Sub']
# 248041 ['Sub']
# 248181 ['Sub']
# 248479 ['M' 'Sub']
# 249137 ['D' 'Sub']
# 249354 ['Sub']
# 249864 ['Sub']
# 250455 ['M' 'Sub']
# 420954 ['Sub']
# 421775 ['Sub']
# 422133 ['Sub']
# 423802 ['D' 'Sub']
# 423803 ['F' 'M' 'Sub']
# 423804 ['F' 'M' 'Sub']
# 423805 ['D' 'F' 'M' 'Sub']
# 423807 ['M' 'Sub']
# 424528 ['D']
# 424532 ['Sub']
# 424535 ['M']
# 424809 ['D' 'Sub']
# 425086 ['Sub']
# 428580 ['D' 'F' 'M' 'Sub']
# 429031 ['Sub']
# 429032 ['Sub']
# 429773 ['D' 'M' 'Sub']
# 429775 ['Sub']
# 429888 ['M' 'Sub']
# 430368 ['F' 'Sub']
# 431799 ['F' 'Sub']
# 432363 ['Sub']
# 433055 ['Sub']
# 433463 ['D' 'Sub']
# 434099 ['Sub']
# 435556 ['F' 'Sub']
# 436636 ['M' 'Sub']
# 438251 ['F' 'Sub']
# 440088 ['F' 'Sub']
# 440089 ['F' 'M' 'Sub']
# 440135 ['GK' 'Sub']
# 443217 ['Sub']
# 445731 ['M' 'Sub']
# 445733 ['Sub']
# 445891 ['D' 'Sub']
# 446023 ['D' 'Sub']
# 446250 ['F' 'Sub']
# 446335 ['Sub']
# 447810 ['F' 'Sub']
# 448115 ['Sub']
# 449154 ['Sub']
# 449213 ['Sub']
# 449331 ['Sub']
# 449336 ['Sub']
# 449452 ['Sub']
# 449741 ['Sub']
# 449893 ['Sub']
# 449897 ['D' 'M' 'Sub']
# 449901 ['Sub']
# 450331 ['D' 'Sub']
# 451410 ['D' 'Sub']
# 451411 ['M']
# 451413 ['Sub']
# 451505 ['Sub']
# 453905 ['D' 'M' 'Sub']
# 453931 ['Sub']
# 453941 ['F' 'M' 'Sub']
# 454656 ['Sub']
# 454657 ['Sub']
# 454659 ['Sub']
# 454660 ['F' 'Sub']
# 454664 ['Sub']
# 454667 ['Sub']
# 455371 ['M' 'Sub']
# 455740 ['Sub']
# 456052 ['F' 'M' 'Sub']
# 456053 ['Sub']
# 458302 ['Sub']
# 460836 ['Sub']
# 460842 ['F' 'M' 'Sub']
# 461266 ['M' 'Sub']
# 462454 ['Sub']
# 462998 ['F' 'Sub']
# 463162 ['Sub']
# 463903 ['Sub']
# 466314 ['Sub']
# 466320 ['Sub']
# 466322 ['Sub']
# 466362 ['Sub']
# 466812 ['M' 'Sub']
# 467189 ['Sub']
# 469584 ['Sub']
# 471228 ['Sub']
# 471464 ['Sub']
# 472185 ['Sub']
# 472744 ['Sub']
# 474818 ['M' 'Sub']
# 477075 ['Sub']
# 477078 ['Sub']
# 477079 ['Sub']
# 478345 ['Sub']
# 478956 ['Sub']
# 479620 ['Sub']
# 482092 ['Sub']

# %%
players_df[players_df['Playerid']==45097]
# Out:
#       Match ID  Team  Playerid            Player name  Jersey Num  \
# 241     984461  Away     45097  Mikkel Rygaard Jensen           7
# 548     984472  Home     45097  Mikkel Rygaard Jensen           7
# 640     984475  Away     45097  Mikkel Rygaard Jensen           7
# 861     984481  Away     45097  Mikkel Rygaard Jensen           7
# 1121    984490  Home     45097  Mikkel Rygaard Jensen           7
# 1485    984500  Home     45097  Mikkel Rygaard Jensen           7
# 1787    984508  Away     45097  Mikkel Rygaard Jensen           7
# 1887    984511  Home     45097  Mikkel Rygaard Jensen           7
# 2120    984517  Away     45097  Mikkel Rygaard Jensen           7
# 2380    984525  Home     45097  Mikkel Rygaard Jensen           7
# 2611    984531  Away     45097  Mikkel Rygaard Jensen           7
# 3026    984543  Home     45097  Mikkel Rygaard Jensen           7
# 3153    984546  Away     45097  Mikkel Rygaard Jensen           7
# 3385    984554  Home     45097  Mikkel Rygaard Jensen           7
# 3773    984564  Away     45097  Mikkel Rygaard Jensen           7
# 3926    984569  Home     45097  Mikkel Rygaard Jensen           7
# 4268    984578  Away     45097  Mikkel Rygaard Jensen           7
# 4967    984598  Home     45097  Mikkel Rygaard Jensen           7
# 5221    984605  Home     45097  Mikkel Rygaard Jensen           7
# 5524    984613  Away     45097  Mikkel Rygaard Jensen           7
# 5902    984625  Home     45097  Mikkel Rygaard Jensen           7
# 6066    984629  Away     45097  Mikkel Rygaard Jensen           7
#
#      Starting Position Starts Match start_pos_super
# 241                 FW        Start               F
# 548                 FW        Start               F
# 640                Sub          Sub             Sub
# 861                Sub          Sub             Sub
# 1121                RM        Start               M
# 1485               Sub          Sub             Sub
# 1787                RM        Start               M
# 1887               Sub          Sub             Sub
# 2120               Sub          Sub             Sub
# 2380                RM        Start               M
# 2611                LM        Start               M
# 3026                RM        Start               M
# 3153                RM        Start               M
# 3385                RM        Start               M
# 3773               Sub          Sub             Sub
# 3926                RM        Start               M
# 4268                CM        Start               M
# 4967                CM        Start               M
# 5221                CM        Start               M
# 5524                CD        Start               D
# 5902                CM        Start               M
# 6066                CM        Start               M

# %%
players_df[['Match ID', 'Playerid', 'start_pos_super']]
# Out:
#       Match ID  Playerid start_pos_super
# 0       984455     50310              GK
# 1       984455    247047               D
# 2       984455    207273               D
# 3       984455     56317               D
# 4       984455     52560               D
# ...        ...       ...             ...
# 6251    984634     90125             Sub
# 6252    984634    225006             Sub
# 6253    984634    429775             Sub
# 6254    984634    425086             Sub
# 6255    984634    460836             Sub
#
# [6256 rows x 3 columns]

# %% [markdown]
# # Fatigue Model

# %% [markdown]
# ## Fit 2nd degree polynomial on energy expenditure

# %%
from scipy.optimize import curve_fit
from collections import defaultdict

# %%
def poly_2nd(x, b, c):
    return 0 + (b * x) + (c * x ** 2)

def plays_full_game(EX_series, thresh=0.95):
    is_full = np.count_nonzero(EX_series)/len(EX_series) > thresh 
    return is_full

# %%
coefs = []

# for each game
for match_id, data in data_dict.items():    
    for _, player_id, series in data['energy_x']:
        EX_cumul = np.cumsum(series)
        frame_lst = np.array(range(len(EX_cumul)))
        
        # check if is subbed out
        if not plays_full_game(series):
            continue
        
        # fit second degree polynomial that passes through origin
        popt, pcov = curve_fit(poly_2nd, frame_lst, EX_cumul)
        
        
        # store info
        coefs.append([match_id, player_id, *popt, *np.sqrt(np.diag(pcov))])
        
    print('Done with match {}'.format(match_id))
# Out:
# Done with match 984554
# Done with match 984509
# Done with match 984590
# Done with match 984539
# Done with match 984530
# Done with match 984481
# Done with match 984495
# Done with match 984468
# Done with match 984460
# Done with match 984523
# Done with match 984570
# Done with match 984579
# Done with match 984505
# Done with match 984558
# Done with match 984476
# Done with match 984491
# Done with match 984455
# Done with match 984518
# Done with match 984544
# Done with match 984575

# %%
# dataframe of coefficients
df_coefs = pd.DataFrame(coefs, 
                        columns=['match_id', 'player_id', 'b1', 'b2', 'sigma_b1', 'sigma_b2'])

# %%
df_coefs.sample(5)
# Out:
#     match_id  player_id         b1        b2  sigma_b1      sigma_b2
# 304   984544     160844  12.652660 -0.000008  0.001177  1.046154e-08
# 12    984554      13737  11.328242 -0.000005  0.001261  1.091152e-08
# 273   984455     229218  11.556559 -0.000006  0.001974  1.785393e-08
# 269   984455     116697   8.543368  0.000004  0.001783  1.612860e-08
# 176   984570     213602  13.786106 -0.000010  0.001526  1.378746e-08

# %% [markdown]
# ## Merge player data

# %%
# add in info 
df_coefs_w_info = pd.merge(df_coefs.astype({'match_id':int}),
                            players_df[['Match ID', 'Playerid', 'start_pos_super', 'Team']],
                            left_on=['match_id', 'player_id'],
                            right_on=['Match ID', 'Playerid'],
                            how='left').drop(['Match ID', 'Playerid'], axis=1)

# %% [markdown]
# # Distribution of coefficients

# %%
# get players who play the most, filter out player with few games
n_games = df_coefs['player_id'].value_counts()
most_play_players = n_games[n_games > 5]

# %%
# distribution per player
coefs_per_player = df_coefs_w_info.set_index('player_id')\
                                  .loc[most_play_players.index]\
                                  .reset_index()

# %%
coefs_per_player.head()
# Out:
#    player_id  match_id        b1            b2  sigma_b1      sigma_b2  \
# 0     182413    984554  3.335275  2.965753e-06  0.000890  7.704964e-09
# 1     182413    984509  3.385095 -2.696467e-06  0.000519  4.615550e-09
# 2     182413    984590  3.285198  1.225754e-06  0.000783  6.905114e-09
# 3     182413    984539  3.463827 -9.692025e-07  0.001054  9.182158e-09
# 4     182413    984530  4.153215 -4.116080e-06  0.000800  7.014023e-09
#
#   start_pos_super  Team
# 0              GK  Away
# 1              GK  Home
# 2              GK  Away
# 3              GK  Away
# 4              GK  Home

# %% [markdown]
# ### B1

# %%
# plot b1
sns.catplot(data=coefs_per_player, x='player_id', y='b1', height=5, aspect=2)
plt.title('Distribution of b1 coefficient per player in Aalborg team')
plt.show()

# %%
g.map(plt.errorbar, "size", "total_bill", "CI", marker="o")

# %%
# per position
g = sns.catplot(data=df_coefs_w_info, 
            x='start_pos_super', y='b1',
              
            height=7, aspect=2)
plt.title('Distribution of b1 coefficient per position in Aalborg team')
# g._legend.remove()

# g.map(plt.errorbar, "start_pos_super", "b1", "sigma_b1", marker=".")

plt.show()

# %% [markdown]
# ### B2

# %%
# coef b2

# needed because of seaborn problem
df_coefs_w_info['b2*10000'] =  df_coefs_w_info['b2'] * 10000

# plot
sns.catplot(data=df_coefs_w_info, x='start_pos_super', y='b2*10000', height=5, aspect=2)
plt.title('Distribution of b2 coefficient per position in Aalborg team')
plt.show()

# %%
# plot
sns.catplot(data=df_coefs_w_info, 
            x='start_pos_super', y='b2*10000', hue='Team',
            height=5, aspect=2)
plt.title('Distribution of b2 coefficient per position and team  in Aalborg team')
plt.show()

# %% [markdown]
# # Anomalies
#
# ### B2 coefficient positive

# %%
# Out:
#    player_id  match_id        b1        b2  sigma_b1      sigma_b2  \
# 2     182413    984590  3.285198  0.000001  0.000783  6.905114e-09
#
#   start_pos_super  Team
# 2              GK  Away

# %%
# find anomaly
b2_anomalies = coefs_per_player[coefs_per_player['b2']>0]
b2_abomaly_toplot = b2_anomalies.sample()

# get EX series
b2_anomaly_EX_series = np.cumsum([y for (_, x, y) in data_dict[str(b2_abomaly_toplot['match_id'].values[0])]['energy_x'] 
                                     if x == b2_abomaly_toplot['player_id'].values[0]][0])

# fit poly
xs = np.array(range(len(b2_anomaly_EX_series)))
b2_abomaly_toplot['b1'] * xs + b2_abomaly_toplot['b2']
# Out:
#   File "<ipython-input-188-06983f43e2f3>", line 12
#     b2_anomaly_fit_poly =
#                           ^
# SyntaxError: invalid syntax

# %%
popt
# Out:
# array([3.28519791e+00, 1.22575438e-06])

# %%
# plot 
f, ax = plt.subplots(figsize=(9, 6))
ax.plot(b2_anomaly_EX_series)
ax.plot
plt.show()

# %%
popt
# Out:
# array([ 1.28601371e+01, -1.55829725e-05])

# %% [markdown]
# # Integrate player features to model
# ### Get player features

# %%
# read  player data
danish_player_data = pd.read_csv('../DanishSuperLiga_1819_PlayerData.csv')

# get player id to name mapping
name_and_id = players_df[['Playerid', 'Player name', 'first_name', 'last_name']].drop_duplicates()


# split first and last name
first_last = danish_player_data['Player'].str.split(expand=True, n=1)
first_last.columns = ['first_name', 'last_name']
danish_player_data[['first_name', 'last_name']] = first_last

# %%
# get player id in the player data
for i, first, last, name in danish_player_data[['first_name', 'last_name', 'Player']].reset_index().values:
    # last name
    last_matches = name_and_id['Player name'].str.contains(last)
    
    # first name
    if last_matches.any():
        first_matches = name_and_id[last_matches]['first_name'].str.slice(stop=1).str.contains(first[0])
        if len(first_matches[first_matches].index) == 1:
            p_id = name_and_id.loc[first_matches[first_matches].index]['Playerid']
            
            # set
            danish_player_data.loc[i, 'player_id'] = p_id.values[0]
        else:
            print(len(first_matches[first_matches].index))
# Out:
# R. Skov
# 482092
#
# A. Skov Olsen
# None
#
# V. Fischer
# None
#
# P. Onuachu
# 0
#
# D. Vavro
# None
#
# M. Duelund
# None
#
# B. Sanneh
# None
#
# Evander Evander
# None
#
# H. Mukhtar
# None
#
# P. Ankersen
# None
#
# R. Falk
# None
#
# V. Nelsson
# None
#
# M. Jensen
# 3
#
# J. Andersson
# None
#
# S. Tibbling
# None
#
# J. Joronen
# None
#
# A. Bjelland
# None
#
# Zeca Zeca
#
# K. Bartolec
# None
#
# E. Sviatchenko
# None
#
# A. Scholz
# None
#
# A. Mabil
# None
#
# C. Nørgaard
#
# M. Damsgaard
# None
#
# M. Kofod Andersen
#
# J. Wind
# None
#
# J. Greguš
#
# S. Hedlund
# None
#
# G. Donyoh
# None
#
# A. Petre
# None
#
# J. Lungi Sørensen
#
# N. Boilesen
# None
#
# G. Varela
# None
#
# N. Thomsen
# None
#
# L. Andersen
# None
#
# K. Hansen
# 2
#
# M. Dal Hende
# None
#
# G. Wikheim
# None
#
# F. Onyeka
# None
#
# L. Vigen Christensen
# None
#
# J. Larsson
# None
#
# R. Kurzawa
# None
#
# K. Wilczek
# None
#
# J. Radošević
#
# P. Sotiriou
# None
#
# R. Mudražija
#
# L. Parunashvili
# None
#
# M. Kristensen
# 2
#
# T. van Weert
# None
#
# K. Kusk
# None
#
# J. Okore
# None
#
# M. Bundu
# None
#
# S. Grytebust
# None
#
# S. Papagiannopoulos
# None
#
# J. Stage
# None
#
# A. Jovanović
#
# M. Schwäbe
#
# M. Jørgensen
#
# M. Daramy
# None
#
# U. Yttergård Jenssen
#
# M. Pedersen
# 3
#
# D. N'Doye
# None
#
# Kenan Kodro
# None
#
# B. Hamid
# None
#
# J. Tverskov
# None
#
# M. Kudus
# None
#
# J. Christensen
# None
#
# S. Lobzhanidze
# None
#
# H. Hermannsson
# None
#
# J. Gammelby
# None
#
# M. Uhre
# None
#
# R. Laursen
# None
#
# J. Laursen
# None
#
# Allan Sousa
# None
#
# S. Gartenmann
# None
#
# M. Rasmussen
# 3
#
# J. Amon
# 2
#
# R. Leeuwin
# None
#
# J. Lauridsen
# None
#
# Y. Yakovenko
# None
#
# J. Rinne
# None
#
# F. Børsting
#
# O. Abildgaard
# None
#
# M. Christensen
# 2
#
# R. Thellufsen
# None
#
# M. Amini
# None
#
# J. Ankersen
# None
#
# C. Højer Nielsen
#
# C. Holse
# None
#
# P. Carlgren
# None
#
# R. Nicolaisen
# None
#
# K. Mensah
# None
#
# A. Jung
# None
#
# M. Rygaard
# None
#
# B. Kadrii
# None
#
# D. Kaiser
# None
#
# A. Ludwig
# None
#
# A. Erceg
# None
#
# B. Halimi
# None
#
# J. Kabongo
# None
#
# M. Rømer
#
# C. Jakobsen
# None
#
# A. Bah
# None
#
# N. Larsen
# None
#
# T. Kløve
#
# J. Kauko
# None
#
# J. Højbjerg
#
# T. Sana
# None
#
# P. Mortensen
# None
#
# N. Helenius
# None
#
# N. Poulsen
# None
#
# M. Lüftner
#
# A. Dreyer
# None
#
# H. Hansson
# None
#
# B. Jacobsen
# None
#
# P. Bengtsson
# None
#
# P. Kirkevold
# None
#
# E. Sabbi
# None
#
# A. Tighadouini
# None
#
# R. Lauritsen
# None
#
# J. Bager
# None
#
# P. Kanstrup
# None
#
# P. Ochs
# None
#
# C. Nielsen
# 2
#
# N. Strunck Jakobsen
# None
#
# V. Hammershøj-Mistrati
#
# D. Mikanović
#
# A. Rømer
#
# J. Thomasen
# None
#
# M. Rojas
# None
#
# M. Lieder
# None
#
# J. Drachmann
# None
#
# A. Jacobsen
# None
#
# M. Brink
# None
#
# D. Anyembe
# None
#
# J. Ahlmann
# None
#
# S. Nilsen
# None
#
# J. Pohl
# None
#
# E. Marxen
# None
#
# M. Kallesøe
#
# J. Hansen
# 2
#
# M. George
# None
#
# M. Thychosen
# None
#
# B. Röcker
#
# P. Arajuuri
# None
#
# N. Mirković
#
# E. Babayan
# None
#
# M. Egho
# None
#
# D. König
#
# W. Ali
# None
#
# M. Greve
# 2
#
# M. Lund
# None
#
# J. Eskesen
# None
#
# Y. Ramadani
# None
#
# E. Jónsson
#
# M. Pedersen
# 3
#
# S. Mielitz
# None
#
# V. Tranberg
# None
#
# A. Mumin
# None
#
# J. Brinch
# None
#
# E. Oti
# None
#
# J. Juelsgård
#
# J. Thorsteinsson
# None
#
# K. Grabara
# None
#
# A. Ammitzbøll
#
# M. Pusic
# None
#
# A. Guira
# None
#
# M. Delač
#
# N. Brock-Madsen
# None
#
# R. Frantsen
# None
#
# K. Junker
# None
#
# M. Qvist
# None
#
# J. Kristoffersen
# None
#
# M. Wohlgemuth
# None
#
# M. Steinmann
# None
#
# A. Skovgaard
# None
#
# B. Kopplin
# None
#
# B. Stokke
# None
#
# J. Poulsen
# None
#
# T. Sparv
# None
#
# S. Reese
# None
#
# A. Okosun
# None
#
# S. Skytte
# None
#
# M. Hallberg
# None
#
# K. Pedersen
# None
#
# K. Fisker
# None
#
# U. Bech
# None
#
# M. Desler
# None
#
# K. Enghardt
# None
#
# M. Aaquist
# None
#
# B. Hansen
# 2
#
# R. Hassan
# None
#
# P. Buch Christiansen
#
# K. Lunding
# None
#
# M. Greve
# 2
#
# J. Schoop
# None
#
# V. Davidsen
# None
#
# L. Jensen
# None
#
# M. Amundsen
# None
#
# T. Mølgaard
#
# K. Luijckx
# None
#
# I. Jónsson
#
# J. Grønning
#
# M. Knudsen
# None
#
# K. Pallesen
# None
#
# J. Blåbjerg
#
# Y. Toutouh
# None
#
# B. Blume
# None
#
# A. Munksgaard
# None
#
# M. Lumb
# None
#
# M. Nielsen
# None
#
# S. Murray
# None
#
# J. Brix-Damborg
#
# M. Hvilsom
# None
#
# J. Bøge
#
# R. Minor Petersen
# None
#
# M. Haarup
# None
#
# D. Christensen
# None
#
# M. Knudsen
# None
#
# S. Henriksen
# None
#
# E. Ogude
# None
#
# A. Kaltoft
# None
#
# F. Lauenborg
# None
#
# E. Riis
# 0
#
# B. Kraev
# None
#
# M. Juel Andersen
#
# D. McGowan
# None
#
# M. Opondo
# None
#
# A. Albers
#
# Al-Hadji Kamara
# None
#
# F. Tingager
# None
#
# M. Spelmann
# None
#
# F. Lesniak
# None
#
# V. Yurchenko
# None
#
# T. Hagelskjær
#
# K. Memija
# None
#
# S. Gryn
# None
#
# Ar. Mucolli
# None
#
# N. Laursen
# None
#
# J. Absalonsen
# None
#
# S. Frederiksen
# None
#
# J. Simonsen
# None
#
# V. Ekani
# None
#
# P. Vindahl Jensen
# None
#
# O. Lund
# None
#
# F. Gytkjær
#
# C. Sivebæk
#
# M. Agger
#
# N. Boxall
#
# N. Backman
# None
#
# Óscar Whalley
# 0
#
# S. Hausner
# None
#
# K. Vacek
# None
#
# O. Drost
# None
#
# M. Roerslev
# None
#
# J. Rask
# None
#
# F. Putros
# None
#
# M. Pedersen
# 3
#
# S. Fischer
# None
#
# A. Juel Andersen
#
# T. Konaté
#
# N. Flø
#
# M. Frankoch
# None
#
# K. Conboy
# None
#
# M. Andersen
# 3
#
# Z. Korcsmár
#
# A. Dovbyk
# None
#
# Y. Amankwah
# None
#
# Francisco Júnior
#
# Brandão Brandão
#
# V. Emmerson
# None
#
# K. Riis
# None
#
# J. Allansson
# None
#
# M. James
# None
#
# P. Šafranko
#
# Júnior Brumado
#
# M. Sayouba
# 0
#
# O. Christensen
# None
#
# A. Jakobsen
# None
#
# K. Finnbogason
# None
#
# M. Lauritsen
# None
#
# I. Louati
# None
#
# M. Hebo Rasmussen
# None
#
# G. Nilsson
# None
#
# D. Amankwaa
# None
#
# N. Marfelt
# None
#
# L. Nielsen
# 0
#
# J. Christjansen
#
# R. Austin
# None
#
# J. Mensah
# 0
#
# F. Brandhof
#
# C. Moses
# 0
#
# M. Ross
#
# K. Mendoza
# None
#
# M. Clausen
#
# S. Avanzini
#
# L. Andreasen
#
# J. Borring
# None
#
# M. Mikkelsen
# 2
#
# S. Adekoya
# None
#
# S. Czajkowski
# None
#
# S. Grønning
#
# N. Baden Frederiksen
# None
#
# M. Mølvadgaard
#
# N. Røjkjær
#
# G. Marcussen
#
# N. Hagelskjær
#
# João Pereira
# None
#
# M. Ørnskov
#
# L. Fosgaard
#
# N. Geertsen
#
# K. Tshiembe
#
# M. Halsti
# None
#
# A. Fischer
# 0
#
# J. Andersen
# 0
#
# P. Kristensen
# None
#
# Q. Antipas
# None
#
# T. Kortegaard
# None
#
# S. Andersen
# None
#
# J. Tjørnelund
#
# O. Thychosen
# 0
#
# N. Gotfredsen
# None
#
# J. Svenningsen
# None
#
# B. Källman
#
# M. Boman
# None
#
# J. Thomsen
# None
#
# T. Damsgaard
# None
#
# N. Oduwa
# None
#
# M. Slavov
# None
#
# D. Fall
# None
#
# J. Kjær
#
# M. Beck
#
# Ramón Ramón
#
# T. Juel-Nielsen
# None
#
# N. Gouriye
# None
#
# J. Illum
# None
#
# L. Fernandes
# None
#
# Park Jung-Bin
#
# A. Bruhn
# None
#
# R. Mysak
# None
#
# B. Sverrisson
# None
#
# M. Kristensen
# 2
#
# T. Arndal
# None
#
# F. Due
# None
#
# P. Bajza
# None
#
# B. McGrath
# None
#
# B. Bellot
# None
#
# A. Riel
# None
#
# A. Mohammed
# 0
#
# R. Vinderslev
# None
#
# N. Mouritsen
#
# B. Lund
# None
#
# N. Madsen
# 3
#
# S. Nattestad
# None
#
# P. Nymann
# None
#
# J. Hjorth
# None
#
# Agus García
#
# M. Kaastrup
# None
#
# S. Graves Jensen
# None
#
# C. Antwi
# None
#
# M. Lansing
# None
#
# T. Mikkelsen
# 0
#
# A. Sørensen
#
# O. Snorre
#
# R. Kakeeto
# None
#
# Y. Dieudonne
# None
#
# N. Lyngø
#
# M. Frendrup
# None
#
# S. Jarović
#
# W. Tchuameni
# None
#
# J. Rothmann
# None
#
# E. Simonsen
# 0
#
# S. Bækgård
#
# M. Solberg
# None
#
# C. Tanor
# None
#
# B. Hvidt
# None
#
# D. Thøgersen
#
# F. Fridriksson
# None
#
# M. Mikkelsen
# 2
#
# K. Høgh
#
# J. Dakir
# None
#
# O. Ottesen
# None
#
# J. Cajuste
# None
#
# M. Tørnes
#
# A. Bruus
# None
#
# R. Charles-Cook
# None
#
# B. Bytyqi
# None
#
# W. Møller
#
# I. Sadiq
# 0
#
# N. Madsen
# 3
#
# M. Larsen
# None
#
# K. Kristensen
# None
#
# B. Ilič
#
# M. Hermansen
# None
#
# M. Kaufmann
# None
#
# J. Steffensen
# None
#
# L. From
# None
#
# Zhenao Wang
# None
#
# G. Zanette
# None
#
# T. Gundelund
# None
#
# A. Skipper
#
# J. Pedersen
# None
#
# I. Atanga
#
# M. Wørts
#
# V. Smedsrud
# None
#
# L. Talbro
# None
#
# E. Damgaard
# 0
#
# M. Frese
# None
#
# J. Harboe
#
# M. Frøkjær-Jensen
#
# A. Daghim
# None
#
# F. Winther
#
# M. Westergaard
#
# J. Mortensen
# None
#
# L. Mikkelsen
# None
#
# C. Dursun
#
# T. Kristensen
# 0
#
# S. Trier
#
# A. Bærtelsen
#
# K. Moesgaard
#
# J. Sery
#
# F. Nørgaard
#
# F. Ibsen
# None
#
# A. Baun
# None
#
# A. Kappenberger
# None
#
# N. Gribenco
# None
#
# M. Dongsted
# None
#
# S. Bugge Jepsen
#
# F. Mortensen
# None
#
# T. Rohde
# None
#
# J. Skov Hansen
# None
#
# M. Lassen
#
# L. Klitten
# None
#
# J. Lindstrøm
#
# M. Gudmann
# None
#
# M. Skjellerup
# None
#
# H. Bernat
# None
#
# O. Olsen
# None
#
# C. Cappis
# None
#
# M. Kikkenborg
#
# D. Andersen
# None
#
# Qingshen Zeng
# None
#
# L. Hetemi
# None
#
# T. Damgaard
# None
#
# K. Poulsgaard
#
# Mohamed Yusuf
# None
#
# H. Mahdi Hussein
#
# O. Klitten
# None
#
# N. Nurmi
# None
#
# M. Sørensen
#
# C. Monty
#
# J. Sørensen
#
# P. Tjørnelund
#
# M. Zaar
# None
#
# M. Egelund
# 0
#
# R. Mmaee
# None
#
# M. Madsen
# None
#
# M. Præst Nielsen
#
# O. Kristensen
# 0
#
# A. Andreasen
#
# J. Jensen
# None
#
# L. Kryger
# None
#
# A. Egholm
# None
#
# K. Povlsen
# None
#
# K. Jørgensen
#
# T. Blaue Yorn
#
# G. Grubbe
#
# J. Andersen
# 0
#
# D. Obbekjær
#
# O. Antman
# None
#
# T. Klysner
#
# P. Egelund
# None

# %% [markdown]
# ## Build dataset with player info and EX

# %%
# mean EX per player
EX_mean_and_info = pd.merge(
    df_coefs_w_info.groupby('player_id')[['b1', 'b2']].mean().reset_index(),
    danish_player_data,
    on='player_id'
)

# %%
# add in multiple of b2 for visualization perposes
EX_mean_and_info['b2*10000'] = EX_mean_and_info['b2'] * 10000

# %%
EX_mean_and_info.T
# Out:
#                           0            1           2            3    \
# player_id               13994        18150       39737        48337
# b1                    10.1994      13.1257     9.62725      8.55815
# b2               -1.31707e-05 -1.79855e-05 -1.2663e-05 -2.08184e-06
# Player             J. Poulsen     T. Sparv   P. Nymann    D. N'Doye
# Team              Midtjylland  Midtjylland     Horsens    København
# Position           RCMF, LCMF   RCMF, LCMF      RB, RW           CF
# Age                        36           32          36           34
# Market value           400000       400000      150000       900000
# Contract expires   2020-06-30   2020-06-30  2020-06-30   2020-06-30
# Matches played             34           21          33           33
# Minutes played           3078         1734        2690         3013
# Goals                       7            2           2           22
# xG                       5.66         3.19        0.52         14.6
# Assists                     7            0           1            2
# xA                       7.08         0.21        1.33         2.44
# Birth country         Denmark      Finland     Denmark      Senegal
# Passport country      Denmark      Finland     Denmark      Senegal
# Foot                    right         left       right        right
# Height                    181          194         179          186
# Weight                     74           78          75           81
# On loan                    no           no          no           no
# first_name                 J.           T.          P.           D.
# last_name             Poulsen        Sparv      Nymann       N'Doye
# b2*10000            -0.131707    -0.179855    -0.12663   -0.0208184
#
#                            4              5                      6    \
# player_id                48469          48601                  48733
# b1                     7.95185        10.9679                9.74907
# b2                 8.38997e-06   -6.99668e-06           -8.45174e-06
# Player            P. Bengtsson  P. Kristensen             R. Leeuwin
# Team                 København            AaB                     OB
# Position               LB, LWB             RB                   RCB3
# Age                         31             32                     31
# Market value            600000         200000                 700000
# Contract expires    2022-06-30            NaN             2020-06-30
# Matches played              15             14                     23
# Minutes played            1042           1249                   2055
# Goals                        0              1                      2
# xG                        0.16           0.82                   1.29
# Assists                      2              0                      0
# xA                        2.38           1.27                   0.15
# Birth country           Sweden        Denmark            Netherlands
# Passport country        Sweden        Denmark  Netherlands, Suriname
# Foot                      left          right                  right
# Height                     175            173                    187
# Weight                      72             68                     76
# On loan                     no             no                     no
# first_name                  P.             P.                     R.
# last_name            Bengtsson     Kristensen                Leeuwin
# b2*10000             0.0838997     -0.0699668             -0.0845174
#
#                           7            8               9    ...          111  \
# player_id               49829        50310           51585  ...       423807
# b1                    11.2069      4.23239         8.50272  ...      10.4421
# b2               -1.20513e-05 -4.26639e-07     6.76091e-06  ... -8.23558e-06
# Player              M. Halsti   S. Mielitz  D. Christensen  ...  B. Jacobsen
# Team                  Esbjerg  SønderjyskE      Vendsyssel  ...      Horsens
# Position             LCB, RCB           GK    LB, LWB, LB5  ...   LCMF, RCMF
# Age                        35           30              30  ...           25
# Market value           200000       400000          350000  ...       600000
# Contract expires   2020-06-30   2020-06-30      2020-06-30  ...   2021-06-30
# Matches played             33           34              14  ...           31
# Minutes played           3143         3244            1119  ...         2618
# Goals                       0            0               0  ...            2
# xG                       0.65            0            0.11  ...         2.62
# Assists                     0            0               1  ...            0
# xA                       0.45            0            1.95  ...         1.34
# Birth country         Finland      Germany         Denmark  ...      Denmark
# Passport country      Finland      Germany         Denmark  ...      Denmark
# Foot                    right        right            left  ...        right
# Height                    185          190             172  ...          183
# Weight                     84           85              69  ...           76
# On loan                    no           no              no  ...           no
# first_name                 M.           S.              D.  ...           B.
# last_name              Halsti      Mielitz     Christensen  ...     Jacobsen
# b2*10000            -0.120513  -0.00426639       0.0676091  ...   -0.0823558
#
#                                 112          113            114          115  \
# player_id                    424528       429773         430368       435556
# b1                          8.34932      12.4114        14.4242      9.07847
# b2                      7.13021e-06 -1.07182e-05    -1.3508e-05 -7.20714e-06
# Player            R. Minor Petersen    M. Haarup  A. Skov Olsen     O. Drost
# Team                          Hobro        Hobro   Nordsjælland          NaN
# Position                        LCB       LB, RB        CF, RWF           CF
# Age                              30           23             19           23
# Market value                 350000       350000        8000000       300000
# Contract expires         2020-06-30          NaN     2020-06-30          NaN
# Matches played                   33           31             36           21
# Minutes played                 2940         2566           3224         1303
# Goals                             0            1             22            3
# xG                             0.92         0.64          14.24         3.18
# Assists                           0            3              4            0
# xA                                0         2.52           4.68         1.38
# Birth country               Denmark      Denmark        Denmark      Denmark
# Passport country            Denmark      Denmark        Denmark      Denmark
# Foot                           left        right           left        right
# Height                          198          178            188          187
# Weight                           94           70             75           78
# On loan                          no           no             no           no
# first_name                       R.           M.             A.           O.
# last_name            Minor Petersen       Haarup     Skov Olsen        Drost
# b2*10000                  0.0713021    -0.107182       -0.13508   -0.0720714
#
#                              116                  117              118  \
# player_id                 440089               445731           449897
# b1                       14.4377               13.639          11.2739
# b2                  -1.47713e-05         -1.26288e-05     -1.59922e-05
# Player              M. Damsgaard  N. Strunck Jakobsen   J. Christensen
# Team                Nordsjælland         Nordsjælland     Nordsjælland
# Position          LCMF3, AMF, CF    RCMF, RCMF3, LCMF  DMF, RCMF, LCMF
# Age                           19                   19               18
# Market value             1750000               600000           800000
# Contract expires      2022-06-30           2021-06-30              NaN
# Matches played                31                   20               22
# Minutes played              2410                 1062             1438
# Goals                          1                    2                0
# xG                          2.85                 1.78             0.36
# Assists                        4                    0                2
# xA                          4.81                 0.04             0.89
# Birth country            Denmark              Denmark          Denmark
# Passport country         Denmark              Denmark          Denmark
# Foot                       right                right            right
# Height                       180                  182              178
# Weight                        65                   72               65
# On loan                       no                   no               no
# first_name                    M.                   N.               J.
# last_name              Damsgaard     Strunck Jakobsen      Christensen
# b2*10000               -0.147713            -0.126288        -0.159922
#
#                           119              120
# player_id              451410           451411
# b1                    9.64363          13.0248
# b2               -4.68275e-06     -1.55559e-05
# Player             A. Kaltoft      M. Frankoch
# Team               Vendsyssel       Vendsyssel
# Position            LCB, LCB3  DMF, RCMF, LCMF
# Age                        21               23
# Market value           350000           300000
# Contract expires   2020-06-30       2020-06-30
# Matches played             31               13
# Minutes played           2709              963
# Goals                       1                0
# xG                        1.3             0.05
# Assists                     0                0
# xA                       0.12             0.17
# Birth country         Denmark          Denmark
# Passport country      Denmark          Denmark
# Foot                    right            right
# Height                    191              180
# Weight                     85               74
# On loan                    no               no
# first_name                 A.               M.
# last_name             Kaltoft         Frankoch
# b2*10000           -0.0468275        -0.155559
#
# [24 rows x 121 columns]

# %%
EX_mean_and_info.head()
# Out:
#    player_id         b1        b2        Player         Team    Position  Age  \
# 0      13994  10.199429 -0.000013    J. Poulsen  Midtjylland  RCMF, LCMF   36
# 1      18150  13.125744 -0.000018      T. Sparv  Midtjylland  RCMF, LCMF   32
# 2      39737   9.627246 -0.000013     P. Nymann      Horsens      RB, RW   36
# 3      48337   8.558148 -0.000002     D. N'Doye    København          CF   34
# 4      48469   7.951846  0.000008  P. Bengtsson    København     LB, LWB   31
#
#    Market value Contract expires  Matches played  ...    xA  Birth country  \
# 0        400000       2020-06-30              34  ...  7.08        Denmark
# 1        400000       2020-06-30              21  ...  0.21        Finland
# 2        150000       2020-06-30              33  ...  1.33        Denmark
# 3        900000       2020-06-30              33  ...  2.44        Senegal
# 4        600000       2022-06-30              15  ...  2.38         Sweden
#
#    Passport country   Foot  Height Weight On loan first_name  last_name  \
# 0           Denmark  right     181     74      no         J.    Poulsen
# 1           Finland   left     194     78      no         T.      Sparv
# 2           Denmark  right     179     75      no         P.     Nymann
# 3           Senegal  right     186     81      no         D.     N'Doye
# 4            Sweden   left     175     72      no         P.  Bengtsson
#
#    b2*10000
# 0 -0.131707
# 1 -0.179855
# 2 -0.126630
# 3 -0.020818
# 4  0.083900
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Age

# %%
# b1
sns.catplot(x='Age', y='b1*10000',
            data=pd.merge(df_coefs_w_info[['player_id', 'start_pos_super']],
         EX_mean_and_info,
         how='left',
         left_on='player_id', right_on='player_id'
        ), hue='start_pos_super',
           aspect=2, height=7)

plt.title('Scatter plot of mean player b1 coefficient (of EX fit) by Age')
plt.show()

# %%
a = pd.merge(df_coefs_w_info[['player_id', 'start_pos_super']],
         EX_mean_and_info,
         how='left',
         left_on='player_id', right_on='player_id'
        )

# %%
# b1
sns.catplot(x='b1', y='b2*10000',
            data=a[a['start_pos_super'] == 'D'], hue='start_pos_super',
           aspect=2, height=7)

plt.title('Scatter plot of mean player b1 coefficient (of EX fit) by Age')
plt.show()

# %%
# b2
sns.catplot(x='Age', y='b2*10000',
            data=EX_mean_and_info,
           aspect=2, height=5)

plt.title('Scatter plot of mean player b2 coefficient (of EX fit) by Age')
plt.show()

# %% [markdown]
# # Weight

# %%
data = pd.merge(df_coefs_w_info[['player_id', 'start_pos_super']],
         EX_mean_and_info,
         how='left',
         left_on='player_id', right_on='player_id'
        )

sns.catplot(x='Weight', y='b2*10000', 
            data=data, hue='start_pos_super',
           aspect=2, height=7)

plt.title('Scatter plot of b1 coefficient of EX by Weight')
plt.show()

# %%
sns.catplot(x='Weight', y='b2*10000', hue='Position',
            data=EX_mean_and_info,
           aspect=2, height=5)

plt.title('Scatter plot of b2 coefficient of EX by Weight')
plt.show()

# %% [markdown]
# # Other

# %%
EX_mean_and_info.keys()
# Out:
# Index(['player_id', 'b1', 'b2', 'Player', 'Team', 'Position', 'Age',
#        'Market value', 'Contract expires', 'Matches played', 'Minutes played',
#        'Goals', 'xG', 'Assists', 'xA', 'Birth country', 'Passport country',
#        'Foot', 'Height', 'Weight', 'On loan', 'first_name', 'last_name',
#        'b2*10000'],
#       dtype='object')

# %%
sns.catplot(x='Matches played', y='b2*10000', 
            data=EX_mean_and_info,
           aspect=2, height=5)

plt.title('')
plt.show()

# %%
sns.lmplot(x='Assists', y='b2*10000', 
            data=EX_mean_and_info,
           aspect=2, height=5)

plt.title('')
plt.show()
